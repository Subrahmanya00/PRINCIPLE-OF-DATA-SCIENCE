# %% [markdown]
# Data analysis using python libraries,pandas and matplotlib

# %% [markdown]
# use a car1.csv dataset and prform explaratory data analysis  using pandas and matplotlib library function to  manipulates and viualize the data and find insights

# %% [markdown]
# 1.Impoert the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# 2.Load the dataset using pandas read_csv() function

# %%
car=pd.read_csv("/content/car1.csv")

# %% [markdown]
# 3.Display the head of the dataset using the head() function

# %%
car.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
car['wt']='2.620'

# %%
car[car['wt']=='2.620']
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.620  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.620  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  2.620  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  2.620  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  2.620  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  2.620  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  2.620  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  2.620  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  2.620  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  2.620  18.90   1   0
# ...

# %%
car.shape
# Out:
# (32, 12)

# %%
car.info
# Out:
# <bound method DataFrame.info of                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
car['mpg'].astype('category')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   output = repr(obj)
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: category
# Categories (25, float64): [10.4, 13.3, 14.3, 14.7, ..., 27.3, 30.4, 32.4, 33.9]

# %%
car['hp']=car['hp'].astype('category')

# %%
car['wt']=car['wt'].astype('category')

# %%
car.describe(include='category')
# Out:
#          mpg   hp    wt  carb
# count   32.0   32    32    32
# unique  25.0   22    29     6
# top     10.4  180  3.44     2
# freq     2.0    3     3    10

# %%
for col in['mpg','hp']:
  car[col]=car[col].astype('category')
  car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    32 non-null     object
#  1   mpg     32 non-null     category
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     category
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     category
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     category
# dtypes: category(4), float64(3), int64(4), object(1)
# memory usage: 5.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    32 non-null     object
#  1   mpg     32 non-null     category
# ...

# %%
car['am']='1'

# %%
car[car['am']=='1']
wt==car[car['am']=='1']
type(wt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-4215fcfcaf9f> in <cell line: 2>()
#       1 car[car['am']=='1']
# ----> 2 wt==car[car['am']=='1']
#       3 type(wt)
#
# NameError: name 'wt' is not defined

# %%
car['am'].mean()
# Out:
# 0.40625

# %%
am1=car['am']
am1.min(),am1.max(),am1.median(),am1.mean()
# Out:
# (0, 1, 0.0, 0.40625)

# %% [markdown]
# 4.Display the bottoms rows from the dataset using the tail() function

# %%
car.tail(5)
# Out:
#               name   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# 5.Print summary statistics of the dataset using the describe() function

# %%
car.describe(include='all')
# Out:
#              name   mpg        cyl        disp          hp       drat  \
# count          32  32.0  32.000000   32.000000   32.000000  32.000000
# unique         32  25.0        NaN         NaN         NaN        NaN
# top     Mazda RX4  10.4        NaN         NaN         NaN        NaN
# freq            1   2.0        NaN         NaN         NaN        NaN
# mean          NaN   NaN   6.187500  230.721875  146.687500   3.596563
# std           NaN   NaN   1.785922  123.938694   68.562868   0.534679
# min           NaN   NaN   4.000000   71.100000   52.000000   2.760000
# 25%           NaN   NaN   4.000000  120.825000   96.500000   3.080000
# 50%           NaN   NaN   6.000000  196.300000  123.000000   3.695000
# 75%           NaN   NaN   8.000000  326.000000  180.000000   3.920000
# max           NaN   NaN   8.000000  472.000000  335.000000   4.930000
#
#                wt       qsec         vs         am       gear  carb
# ...

# %% [markdown]
# 6.Plot a histogram for all the variables

# %%
sns.histplot(x=car['am'],stat='percent',color='green')
# Out:
# <Axes: xlabel='am', ylabel='Percent'>

# %%
car.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'mpg'}>, <Axes: title={'center': 'cyl'}>,
#         <Axes: title={'center': 'disp'}>],
#        [<Axes: title={'center': 'hp'}>, <Axes: title={'center': 'drat'}>,
#         <Axes: title={'center': 'wt'}>],
#        [<Axes: title={'center': 'qsec'}>, <Axes: title={'center': 'vs'}>,
#         <Axes: title={'center': 'am'}>],
#        [<Axes: title={'center': 'gear'}>,
#         <Axes: title={'center': 'carb'}>, <Axes: >]], dtype=object)

# %% [markdown]
# 7.Box plot to visualize the relationship b/w mpg and hp

# %%
sns.boxplot(x="mpg",y="hp",data=car)
# Out:
# <Axes: xlabel='mpg', ylabel='hp'>

# %% [markdown]
# 8.Build a pair plot using the seaborn library

# %%
sns.pairplot(car)

# %% [markdown]
# 9.Drop irrelevent columns from the dataset using drop() function

# %%
car=car.drop(["name","carb"],axis=1)
car.head(5)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3

# %% [markdown]
# 10.use rename() function to rename the columns

# %%
car=car.rename(columns={"mpg":"car names"})
car.head(5)
# Out:
#    car names  cyl   disp   hp  drat     wt   qsec  vs  am  gear
# 0       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1       21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4       18.7    8  360.0  175  3.15  3.440  17.02   0   0     3

# %% [markdown]
# 11.print the total number of duplicate rows

# %%
duplicate_rows_car=car[car.duplicated()]
print("number of duplicate rows:",duplicate_rows_car.shape)
# Out:
# number of duplicate rows: (0, 10)

# %% [markdown]
# 12.Remove the duplicate  rows using thw drop_duplicates function

# %%
car=car.drop_duplicates()
car.head(10)
# Out:
#    car names  cyl   disp   hp  drat     wt   qsec  vs  am  gear
# 0       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1       21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4       18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5       18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6       14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8       22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9       19.2    6  167.6  123  3.92  3.440  18.30   1   0     4

# %% [markdown]
# 13.Drop the missing values from the dataset

# %%
print(car.isnull().sum())
# Out:
# car names    0
# cyl          0
# disp         0
# hp           0
# drat         0
# wt           0
# qsec         0
# vs           0
# am           0
# gear         0
# dtype: int64

# %%
r=car.dropna()
car.count()
# Out:
# car names    32
# cyl          32
# disp         32
# hp           32
# drat         32
# wt           32
# qsec         32
# vs           32
# am           32
# gear         32
# dtype: int64

# %% [markdown]
# 14.plot a histogram to find the number of cars per brand

# %%
car.hp.value_counts().nlargest(40).plot(kind="bar",figsize=(10,5))
plt.title("number of car by hp")
plt.ylabel("number of cars")
plt.xlabel("hp");

# %% [markdown]
# 15.draw a corelation lot between thw variables

# %%
plt.figure(figsize=(20,10))
c=car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#            car names       cyl      disp        hp      drat        wt  \
# car names   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659
# cyl        -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496
# disp       -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980
# hp         -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748
# drat        0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441
# wt         -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000
# qsec        0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716
# vs          0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916
# am          0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495
# gear        0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287
#
#                qsec        vs        am      gear
# car names  0.418684  0.664039  0.599832  0.480285
# cyl       -0.591242 -0.810812 -0.522607 -0.492687
# ...
