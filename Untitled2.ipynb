# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install jsonlines
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install findspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json
import pandas as pd

# %%
emp=pd.read_csv("/content/emp1.csv")
emp
# Out:
#    NAME OF EMPLOYEE   CTC  BASIC SA    DA  HRA  BONUS  TOTAL
# 0       Subrahmanya  2000     12000  1300  130   2000  17430
# 1            Rajesh  6000     13000  1200  120   3000  23320
# 2            Sonith  4500     18000  1400  140   4000  28040
# 3          Sidharth  2345     15000  1500  150   5000  23995
# 4         Shushanth  1200     12000  1200  120   6000  20520
# 5           Jithesh  6000     15000  1300  120   2000  24420
# 6           Pradeep  2000     18000  1400  140   3000  24540
# 7               Ram  4500     16000  1500  150   4000  26150
# 8            Laxman  3456     16000  1200  120   5000  25776
# 9          Nagendra  7890     18000  1300  120   6000  33310
# 10              Ram  4500     16000  1500  150   4000  26150
# 11            Umesh  1234     12000  1500  150   3000  17884
# 12         Narayana  1234     13000  1200  120   3000  18554
# 13    Chandrashekar  2345     15000  1300  130   4000  22775
# ...

# %%
emp['DA'] [:10]
# Out:
# 0    1300
# 1    1200
# 2    1400
# 3    1500
# 4    1200
# 5    1300
# 6    1400
# 7    1500
# 8    1200
# 9    1300
# Name: DA, dtype: int64

# %%
emp.describe(include='all')
# Out:
#        NAME OF EMPLOYEE          CTC      BASIC SA            DA         HRA  \
# count                20    20.000000     20.000000     20.000000   20.000000
# unique               19          NaN           NaN           NaN         NaN
# top                 Ram          NaN           NaN           NaN         NaN
# freq                  2          NaN           NaN           NaN         NaN
# mean                NaN  4486.900000  15450.000000   2045.000000  136.000000
# std                 NaN  2401.246538   2372.540278   3052.949394   16.026294
# min                 NaN  1200.000000  12000.000000   1200.000000  120.000000
# 25%                 NaN  2258.750000  13000.000000   1200.000000  120.000000
# 50%                 NaN  4500.000000  16000.000000   1350.000000  135.000000
# 75%                 NaN  6000.000000  18000.000000   1500.000000  150.000000
# max                 NaN  7890.000000  18000.000000  15000.000000  170.000000
#
#               BONUS         TOTAL
# ...

# %%
emp.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'CTC'}>,
#         <Axes: title={'center': 'BASIC SA'}>],
#        [<Axes: title={'center': 'DA'}>, <Axes: title={'center': 'HRA'}>],
#        [<Axes: title={'center': 'BONUS'}>,
#         <Axes: title={'center': 'TOTAL'}>]], dtype=object)

# %%
import seaborn as sns
sns.boxplot(x="BONUS",y="DA",data=emp)
# Out:
# <Axes: xlabel='BONUS', ylabel='DA'>

# %%
sns.pairplot(emp)

# %%
duplicate_rows_emp=emp[emp.duplicated()]
print("number of duplicate rows:",duplicate_rows_emp.shape)
# Out:
# number of duplicate rows: (0, 7)

# %%
emp=emp.drop_duplicates()
emp
# Out:
#    NAME OF EMPLOYEE   CTC  BASIC SA    DA  HRA  BONUS  TOTAL
# 0       Subrahmanya  2000     12000  1300  130   2000  17430
# 1            Rajesh  6000     13000  1200  120   3000  23320
# 2            Sonith  4500     18000  1400  140   4000  28040
# 3          Sidharth  2345     15000  1500  150   5000  23995
# 4         Shushanth  1200     12000  1200  120   6000  20520
# 5           Jithesh  6000     15000  1300  120   2000  24420
# 6           Pradeep  2000     18000  1400  140   3000  24540
# 7               Ram  4500     16000  1500  150   4000  26150
# 8            Laxman  3456     16000  1200  120   5000  25776
# 9          Nagendra  7890     18000  1300  120   6000  33310
# 11            Umesh  1234     12000  1500  150   3000  17884
# 12         Narayana  1234     13000  1200  120   3000  18554
# 13    Chandrashekar  2345     15000  1300  130   4000  22775
# 14       Gauthamraj  6000     16000  1400  140   4000  27540
# ...

# %%
emp.dropna()
# Out:
#    NAME OF EMPLOYEE   CTC  BASIC SA     DA  HRA  BONUS  TOTAL
# 0       Subrahmanya  2000     12000   1300  130   2000  17430
# 1            Rajesh  6000     13000   1200  120   3000  23320
# 2            Sonith  4500     18000   1400  140   4000  28040
# 3          Sidharth  2345     15000   1500  150   5000  23995
# 4         Shushanth  1200     12000   1200  120   6000  20520
# 5           Jithesh  6000     15000   1300  120   2000  24420
# 6           Pradeep  2000     18000   1400  140   3000  24540
# 7               Ram  4500     16000   1500  150   4000  26150
# 8            Laxman  3456     16000   1200  120   5000  25776
# 9          Nagendra  7890     18000   1300  120   6000  33310
# 10              Ram  4500     16000  15000  150   4000  26150
# 11            Umesh  1234     12000   1500  150   3000  17884
# 12         Narayana  1234     13000   1200  120   3000  18554
# 13    Chandrashekar  2345     15000   1300  130   4000  22775
# ...

# %%
emp.count()
# Out:
# NAME OF EMPLOYEE    20
# CTC                 20
# BASIC SA            20
# DA                  20
# HRA                 20
# BONUS               20
# TOTAL               20
# dtype: int64

# %%
print(emp.isnull().sum())
# Out:
# NAME OF EMPLOYEE    0
# CTC                 0
# BASIC SA            0
# DA                  0
# HRA                 0
# BONUS               0
# TOTAL               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
e=emp.corr()
sns.heatmap(e,cmap="BrBG",annot=True)
e
# Out:
# <ipython-input-97-207484be1e5e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   e=emp.corr()
#                CTC  BASIC SA        DA       HRA     BONUS     TOTAL
# CTC       1.000000  0.595727  0.005499  0.013337  0.197745  0.834509
# BASIC SA  0.595727  1.000000  0.059547  0.077515  0.158849  0.652143
# DA        0.005499  0.059547  1.000000  0.252361 -0.018211  0.019735
# HRA       0.013337  0.077515  0.252361  1.000000 -0.027940  0.204684
# BONUS     0.197745  0.158849 -0.018211 -0.027940  1.000000  0.562861
# TOTAL     0.834509  0.652143  0.019735  0.204684  0.562861  1.000000

# %%
emp.DA.value_counts().nlargest(20).plot(kind="bar",figsize=(10,10))
plt.title("emp sheet")
plt.ylabel("number of emp")
plt.xlabel("DA");
